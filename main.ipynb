# %%
import pandas as pd


df_listing = pd.read_csv('listings.csv')
df_reviews = pd.read_csv('reviews.csv')

# %%
df_listing = pd.read_csv('listings.csv')

df_listing.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  1489424  https://www.airbnb.com/rooms/1489424  20240310234900   2024-03-10
# 1  2992450  https://www.airbnb.com/rooms/2992450  20240310234900   2024-03-11
# 2  3820211  https://www.airbnb.com/rooms/3820211  20240310234900   2024-03-11
# 3  5651579  https://www.airbnb.com/rooms/5651579  20240310234900   2024-03-11
# 4  6623339  https://www.airbnb.com/rooms/6623339  20240310234900   2024-03-11
#
#         source                                              name  \
# 0  city scrape     Welcoming, easygoing, comfy bed, entire level
# 1  city scrape                        Luxury 2 bedroom apartment
# 2  city scrape         Restored Precinct in Center Sq. w/Parking
# 3  city scrape        Large studio apt  by Capital Center & ESP@
# 4  city scrape  Center Sq. Loft in Converted Precinct w/ Parking
#
#                                          description  \
# ...

# %%
print(df_listing.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
# Remoção de colunas não necessárias
colunas_para_remover = ['neighbourhood_group_cleansed', 'license']

df_listing.drop(columns=colunas_para_remover, inplace=True)

# %%
df_listing.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  1489424  https://www.airbnb.com/rooms/1489424  20240310234900   2024-03-10
# 1  2992450  https://www.airbnb.com/rooms/2992450  20240310234900   2024-03-11
# 2  3820211  https://www.airbnb.com/rooms/3820211  20240310234900   2024-03-11
# 3  5651579  https://www.airbnb.com/rooms/5651579  20240310234900   2024-03-11
# 4  6623339  https://www.airbnb.com/rooms/6623339  20240310234900   2024-03-11
#
#         source                                              name  \
# 0  city scrape     Welcoming, easygoing, comfy bed, entire level
# 1  city scrape                        Luxury 2 bedroom apartment
# 2  city scrape         Restored Precinct in Center Sq. w/Parking
# 3  city scrape        Large studio apt  by Capital Center & ESP@
# 4  city scrape  Center Sq. Loft in Converted Precinct w/ Parking
#
#                                          description  \
# ...

# %%
df_reviews = pd.read_csv('reviews.csv')

df_reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1489424  7208791  2013-09-10      5817914        Hilary
# 1     1489424  8001939  2013-10-12      4786919        Sharon
# 2     1489424  8123022  2013-10-16      4786919        Sharon
# 3     1489424  8279957  2013-10-23      8362214        Andrej
# 4     1489424  8303182  2013-10-24      9458270       Andreia
#
#                                             comments
# 0  Efrat and Dan were very welcoming and accommod...
# 1  As advertised, a very comfy bed. Restful room,...
# 2  Glad to be back for a second time in my cozy r...
# 3  We stayed only for a night, so can not tell mu...
# 4  I had a pleasant stay here. The bed was indeed...

# %%
df_calendar = pd.read_csv('calendar.csv')

df_calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-09-23         f  $265.00        $265.00             5.0
# 1       17878  2023-09-24         t  $265.00        $265.00             5.0
# 2       17878  2023-09-25         f  $290.00        $290.00             5.0
# 3       17878  2023-09-26         f  $290.00        $290.00             5.0
# 4       17878  2023-09-27         f  $290.00        $290.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0

# %%
valores_nulos = df_calendar.isnull().sum()
valores_nulos

# %%
remover_nulos = df_calendar.dropna(subset=['minimum_nights', 'maximum_nights'])
remover_nulos

# %%
df_calendar.head()
df_calendar

# %%
df_calendar['date'] = pd.to_datetime(df_calendar['date'])

df_calendar['day'] = df_calendar['date'].dt.day
df_calendar['month'] = df_calendar['date'].dt.month
df_calendar['year'] = df_calendar['date'].dt.year

df_calendar

# %%
df_calendar['price'] = df_calendar['price'].str.replace('$', '').str.replace('.', '')
df_calendar

# %%
df_calendar['adjusted_price'] = df_calendar['adjusted_price'].str.replace('$', '').str.replace('.', '')
df_calendar
